# %%
## DEPENDENCIES
import os
import shutil
import random

# %%
## Connecting to the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## PATHS
images_path = "/content/drive/MyDrive/DROWSINESS/data/images"

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12604, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 12604 (delta 5), reused 15 (delta 1), pack-reused 12579
# Receiving objects: 100% (12604/12604), 12.51 MiB | 30.94 MiB/s, done.
# Resolving deltas: 100% (8629/8629), done.

# %%
# %cd yolov5/
# Out:
# /content/yolov5

# %%
## Install requirements
# !pip install -r requirements.txt

# %%
# !wget https://github.com/ultralytics/yolov5/releases/download/v6.0/yolov5s.pt

# %%
# !python train.py --img 416 --batch 32 --epochs 1200 --data /content/drive/MyDrive/DROWSINESS/dataset.yaml --weights /content/yolov5/yolov5s.pt --nosave --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#                  all        343        388      0.993      0.989      0.995      0.779
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   201/1199     4.19G   0.02519  0.008784  0.002252        47       416: 100% 11/11 [00:02<00:00,  4.07it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:02<00:00,  2.78it/s]
#                  all        343        388      0.993      0.994      0.995      0.779
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#   202/1199     4.19G   0.02609  0.009135   0.00162        46       416: 100% 11/11 [00:03<00:00,  3.17it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 6/6 [00:02<00:00,  2.37it/s]
#                  all        343        388      0.992      0.996      0.995      0.762
#
# ...

# %%
# model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/yolov5/runs/train/exp3/weights/last.pt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e28ea8c6f13f> in <module>()
# ----> 1 model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/yolov5/runs/train/exp3/weights/last.pt')
#
# NameError: name 'torch' is not defined

# %%
## Detect
# !python detect.py --source /content/drive/MyDrive/DROWSINESS/data/test --weights /content/yolov5/runs/train/exp2/weights/last.pt --img 416 --save-txt --save-conf
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/last.pt'], source=/content/drive/MyDrive/DROWSINESS/data/test, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-382-ge242ede Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# image 1/44 /content/drive/MyDrive/DROWSINESS/data/test/awake 0.jpg: 416x288 1 awake, Done. (0.012s)
# image 2/44 /content/drive/MyDrive/DROWSINESS/data/test/awake 1.jpg: 416x352 1 awake, Done. (0.012s)
# image 3/44 /content/drive/MyDrive/DROWSINESS/data/test/awake 10.jpg: 416x288 1 awake, Done. (0.010s)
# ...

# %%
##Display result image
import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp4/*.jpg'): #jpg*
  display(Image(filename = imageName))
  print("\n")

# %%
## DOWNLOAD WEIGHTS
from google.colab import files
files.download('/content/yolov5/runs/train/exp2/weights/last.pt')
